# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehadi4021/Digital-Image-Processing_Lab_CSE438/blob/main/Lab_Assignment_Md_Mehadi_Hasan_2125051003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name:Md.Mehadi Hasan
# ID:2125051003

# %% [markdown]
# Faculty: Audity Ghosh
# Lecturer, Department of Computer Science & Engineering, University of Information Technology and Sciences (UITS)
#
# Course Code: CSE 438
# Course Title: Digital Image Processing Lab
# Section: 8A (50th Batch)
# Submission Date: 10 February, 2025

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import urllib.request
import numpy as np

# %%
# Step 1: Provide the URL of the image
image_url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcREoRGyXmHy_6aIgXYqWHdOT3KjfmnuSyxypw&s'

# %%
# Step 2: Download the image using urllib
with urllib.request.urlopen(image_url) as response:
    img_array = np.asarray(bytearray(response.read()), dtype=np.uint8)  # Convert to NumPy array

# %%
# Step 3: Decode the image (convert it into OpenCV format)
img = cv2.imdecode(img_array, cv2.IMREAD_COLOR)  # Decode as a color image (BGR format)

# %%
# Step 4: Convert BGR to RGB for correct display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Step 5: Display the image using Matplotlib
plt.imshow(img_rgb)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Image from URL")
plt.show()

# %% [markdown]
# Task-01: Extract a 100×100 Region from the Center of the Image read from an URL.

# %%
# Step 4: Get image dimensions
height, width, _ = img_rgb.shape

# Step 5: Calculate center coordinates
center_x = width // 2
center_y = height // 2

# Step 6: Define cropping region
start_x = center_x - 50  # 50 pixels to the left of the center
start_y = center_y - 50  # 50 pixels above the center
end_x = center_x + 50   # 50 pixels to the right of the center
end_y = center_y + 50   # 50 pixels below the center

# Step 7: Crop the image
cropped_img = img_rgb[start_y:end_y, start_x:end_x]



plt.imshow(cropped_img)
plt.axis('off')
plt.title("Cropped 100×100 Region")
plt.show()

# %% [markdown]
# Task 2:  Convert the image to HSV color space, visualize each components in grayscale representation.

# %%
hsv_image = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
h_channel, s_channel, v_channel = cv2.split(hsv_image)

# %%
plt.subplot(1, 3, 1)
plt.imshow(h_channel, cmap="gray")
plt.axis("off")
plt.title("Hue Channel (H)")

plt.subplot(1, 3, 2)
plt.imshow(v_channel, cmap="gray")
plt.title("Value Channel (V)")
plt.axis("off")


plt.subplot(1, 3, 3)
plt.imshow(s_channel, cmap="gray")
plt.title("Saturation Channel (S)")
plt.axis("off")


plt.tight_layout()
plt.show()
